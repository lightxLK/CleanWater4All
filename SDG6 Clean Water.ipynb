# %% [markdown]
# <h1 align = ' center '> Lokesh Patra </h1>

# %%
wml_credentials={
  "url": "https://us-south.ml.cloud.ibm.com",
  "apikey": "H2aOBKLzHknGhmJyslqGphsXjyRHgoXMfUCugKibE1TD"
}

# %%
scoring_endpoint = 'd65f326b-89c2-4dc3-a025-3d63cd9f1bde'

# %%
# Import the installed WML API client from the ibm_watson_machine_learning python package
from ibm_watson_machine_learning import APIClient

# Create API client
client = APIClient(wml_credentials)

# Set the deployment space
client.set.default_space('a3c09b2b-d25c-4f7e-b485-bffe82a2b661')

# %%
payload_scoring = {
    "input_data": [
        {
            "fields": [
                "pH",
                "Hardness",
                "Solids",
                "Chloramines",
                "Sulfate",
                "Conductivity",
                "Organic_carbon",
                "Trihalomethanes",
                "Turbidity"
            ],
            "values": [
                [7.8, 196.379, 22430, 7.35, 290.0, 380.0, 10.38, 36.9, 2.9]
            ]
        }
    ]
}

client.deployments.score(scoring_endpoint, payload_scoring)
# Out:
# {'predictions': [{'fields': ['prediction', 'probability'],
#    'values': [[1, [0.22154861346647148, 0.7784513865335285]]]}]}

# %% [markdown]
# <h1 align = ' center '> Thank You! </h1>
# <h5 align = ' center '> 1059@sbcsrbox.com </h5>
